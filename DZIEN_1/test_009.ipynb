# %%
print("to jest pierwszy notebook")
# Out:
# to jest pierwszy notebook

# %%
a = 99.9
b = 0.45
c = 1.7e+11

# %%
w = (c-b)/2*a
w
# Out:
# 8491499999977.522

# %% [markdown]
# Start Projektu: <span style="color:green;">**Numpy**</span>,<span style="color:red;">**Pandas**<span>

# %%
lsztuk = 8

# %%
cena = "55.5"

# %%
lsztuk*eval(cena)
# Out:
# 444.0

# %%
with open("dane.txt","r",encoding="utf-8") as f:
    print(f.read())
# Out:
# to jest plik z danymi
# 9568905869548695486945
#     abc abc
# to ostatnia linia
